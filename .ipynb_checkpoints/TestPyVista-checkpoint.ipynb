# %%
#!conda init --all
# !conda install --help
# Out:
# usage: conda install [-h] [--revision REVISION] [-n ENVIRONMENT | -p PATH]
#                      [-c CHANNEL] [--use-local] [--override-channels]
#                      [--repodata-fn REPODATA_FNS] [--strict-channel-priority]
#                      [--no-channel-priority] [--no-deps | --only-deps]
#                      [--no-pin] [--copy] [-C] [-k] [--offline] [-d] [--json]
#                      [-q] [-v] [-y] [--download-only] [--show-channel-urls]
#                      [--file FILE] [--force-reinstall]
#                      [--freeze-installed | --update-deps | -S | --update-all | --update-specs]
#                      [-m] [--clobber] [--dev]
#                      [package_spec ...]
#
# Installs a list of packages into a specified conda environment.
#
#     This command accepts a list of package specifications (e.g, bitarray=0.8)
#     and installs a set of packages consistent with those specifications and
#     compatible with the underlying environment. If full compatibility cannot
#     be assured, an error is reported and the environment is not changed.
#
#     Conda attempts to install the newest versions of the requested packages. To
#     accomplish this, it may update some packages that are already installed, or
#     install additional packages. To prevent existing packages from updating,
#     use the --freeze-installed option. This may force conda to install older
#     versions of the requested packages, and it does not prevent additional
#     dependency packages from being installed.
#
#     If you wish to skip dependency checking altogether, use the '--no-deps'
#     option. This may result in an environment with incompatible packages, so
#     this option must be used with great caution.
#
#     conda can also be called with a list of explicit conda package filenames
#     (e.g. ./lxml-3.2.0-py27_0.tar.bz2). Using conda in this mode implies the
#     --no-deps option, and should likewise be used with great caution. Explicit
#     filenames and package specifications cannot be mixed in a single command.
#
# Options:
#
# positional arguments:
#   package_spec          Packages to install or update in the conda
#                         environment.
#
# optional arguments:
#   -h, --help            Show this help message and exit.
#   --revision REVISION   Revert to the specified REVISION.
#   --file FILE           Read package versions from the given file. Repeated
#                         file specifications can be passed (e.g. --file=file1
#                         --file=file2).
#   --dev                 Use `sys.executable -m conda` in wrapper scripts
#                         instead of CONDA_EXE. This is mainly for use during
#                         tests where we test new conda source against old
#                         Python versions.
#
# Target Environment Specification:
#   -n ENVIRONMENT, --name ENVIRONMENT
#                         Name of environment.
#   -p PATH, --prefix PATH
#                         Full path to environment location (i.e. prefix).
#
# Channel Customization:
#   -c CHANNEL, --channel CHANNEL
#                         Additional channel to search for packages. These are
#                         URLs searched in the order they are given (including
#                         local directories using the 'file://' syntax or simply
#                         a path like '/home/conda/mychan' or '../mychan').
#                         Then, the defaults or channels from .condarc are
#                         searched (unless --override-channels is given). You
#                         can use 'defaults' to get the default packages for
#                         conda. You can also use any name and the .condarc
#                         channel_alias value will be prepended. The default
#                         channel_alias is http://conda.anaconda.org/.
#   --use-local           Use locally built packages. Identical to '-c local'.
#   --override-channels   Do not search default or .condarc channels. Requires
#                         --channel.
#   --repodata-fn REPODATA_FNS
#                         Specify name of repodata on remote server. Conda will
#                         try whatever you specify, but will ultimately fall
#                         back to repodata.json if your specs are not
#                         satisfiable with what you specify here. This is used
#                         to employ repodata that is reduced in time scope. You
#                         may pass this flag more than once. Leftmost entries
#                         are tried first, and the fallback to repodata.json is
#                         added for you automatically.
#
# Solver Mode Modifiers:
#   --strict-channel-priority
#                         Packages in lower priority channels are not considered
#                         if a package with the same name appears in a higher
#                         priority channel.
#   --no-channel-priority
#                         Package version takes precedence over channel
#                         priority. Overrides the value given by `conda config
#                         --show channel_priority`.
#   --no-deps             Do not install, update, remove, or change
#                         dependencies. This WILL lead to broken environments
#                         and inconsistent behavior. Use at your own risk.
#   --only-deps           Only install dependencies.
#   --no-pin              Ignore pinned file.
#   --force-reinstall     Ensure that any user-requested package for the current
#                         operation is uninstalled and reinstalled, even if that
#                         package already exists in the environment.
#   --freeze-installed, --no-update-deps
#                         Do not update or change already-installed
#                         dependencies.
#   --update-deps         Update dependencies.
#   -S, --satisfied-skip-solve
#                         Exit early and do not run the solver if the requested
#                         specs are satisfied. Also skips aggressive updates as
#                         configured by 'aggressive_update_packages'. Similar to
#                         the default behavior of 'pip install'.
#   --update-all, --all   Update all installed packages in the environment.
#   --update-specs        Update based on provided specifications.
#
# Package Linking and Install-time Options:
#   --copy                Install all packages using copies instead of hard- or
#                         soft-linking.
#   -m, --mkdir           Create the environment directory if necessary.
#   --clobber             Allow clobbering of overlapping file paths within
#                         packages, and suppress related warnings.
#
# Networking Options:
#   -C, --use-index-cache
#                         Use cache of channel index files, even if it has
#                         expired.
#   -k, --insecure        Allow conda to perform "insecure" SSL connections and
#                         transfers. Equivalent to setting 'ssl_verify' to
#                         'false'.
#   --offline             Offline mode. Don't connect to the Internet.
#
# Output, Prompt, and Flow Control Options:
#   -d, --dry-run         Only display what would have been done.
#   --json                Report all output as json. Suitable for using conda
#                         programmatically.
#   -q, --quiet           Do not display progress bar.
#   -v, --verbose         Can be used multiple times. Once for INFO, twice for
#                         DEBUG, three times for TRACE.
#   -y, --yes             Do not ask for confirmation.
#   --download-only       Solve an environment and ensure package caches are
#                         populated, but exit prior to unlinking and linking
#                         packages into the prefix.
#   --show-channel-urls   Show channel urls. Overrides the value given by `conda
#                         config --show show_channel_urls`.
#
# Examples:
#
#     conda install -n myenv scipy

# %%
 # !sudo apt install libgl1-mesa-glx xvfb
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   ca-certificates-java cmake-data cuda-command-line-tools-11-2
#   cuda-compiler-11-2 cuda-cudart-11-2 cuda-cudart-dev-11-2 cuda-cuobjdump-11-2
#   cuda-cupti-11-2 cuda-cupti-dev-11-2 cuda-cuxxfilt-11-2
#   cuda-documentation-11-2 cuda-driver-dev-11-2 cuda-gdb-11-2
#   cuda-libraries-11-2 cuda-libraries-dev-11-2 cuda-memcheck-11-2
#   cuda-nsight-11-2 cuda-nsight-compute-11-2 cuda-nsight-systems-11-2
#   cuda-nvcc-11-2 cuda-nvdisasm-11-2 cuda-nvml-dev-11-2 cuda-nvprof-11-2
#   cuda-nvprune-11-2 cuda-nvrtc-11-2 cuda-nvrtc-dev-11-2 cuda-nvtx-11-2
#   cuda-nvvp-11-2 cuda-samples-11-2 cuda-sanitizer-11-2 cuda-toolkit-11-2
#   cuda-tools-11-2 cuda-visual-tools-11-2 default-jre default-jre-headless
#   fonts-dejavu-extra gyp java-common javascript-common libarchive13 libasound2
#   libasound2-data libatk-wrapper-java libatk-wrapper-java-jni libc-ares2
#   libcublas-11-2 libcublas-dev-11-2 libcufft-11-2 libcufft-dev-11-2
#   libcurand-11-2 libcurand-dev-11-2 libcusolver-11-2 libcusolver-dev-11-2
#   libcusparse-11-2 libcusparse-dev-11-2 libjs-async libjs-inherits
#   libjs-jquery libjs-node-uuid libjs-underscore libjsoncpp1 libnpp-11-2
#   libnpp-dev-11-2 libnspr4 libnss3 libnvidia-common-510 libnvjpeg-11-2
#   libnvjpeg-dev-11-2 libpcsclite1 librhash0 libuv1-dev
#   linux-headers-4.15.0-166 node-abbrev node-ansi node-ansi-color-table
#   node-archy node-async node-balanced-match node-block-stream
#   node-brace-expansion node-builtin-modules node-combined-stream
#   node-concat-map node-cookie-jar node-delayed-stream node-forever-agent
#   node-form-data node-fs.realpath node-fstream node-fstream-ignore
#   node-github-url-from-git node-glob node-graceful-fs node-hosted-git-info
#   node-inflight node-inherits node-ini node-is-builtin-module node-isexe
#   node-json-stringify-safe node-lockfile node-lru-cache node-mime
#   node-minimatch node-mkdirp node-mute-stream node-node-uuid node-nopt
#   node-normalize-package-data node-npmlog node-once node-osenv
#   node-path-is-absolute node-pseudomap node-qs node-read
#   node-read-package-json node-request node-retry node-rimraf node-semver
#   node-sha node-slide node-spdx-correct node-spdx-expression-parse
#   node-spdx-license-ids node-tar node-tunnel-agent node-underscore
#   node-validate-npm-package-license node-which node-wrappy node-yallist
#   nsight-compute-2020.3.1 nsight-systems-2020.4.3 openjdk-11-jre
#   openjdk-11-jre-headless python-pkg-resources
# Use 'sudo apt autoremove' to remove them.
# The following NEW packages will be installed:
#   libgl1-mesa-glx xvfb
# 0 upgraded, 2 newly installed, 0 to remove and 36 not upgraded.
# Need to get 789 kB of archives.
# After this operation, 2351 kB of additional disk space will be used.
# Get:1 http://azure.archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgl1-mesa-glx amd64 20.0.8-0ubuntu1~18.04.1 [5532 B]
# Get:2 http://azure.archive.ubuntu.com/ubuntu bionic-updates/universe amd64 xvfb amd64 2:1.19.6-1ubuntu4.10 [784 kB]
# Fetched 789 kB in 0s (2708 kB/s)m
#
# 78Selecting previously unselected package libgl1-mesa-glx:amd64.
# (Reading database ... 231921 files and directories currently installed.)
# Preparing to unpack .../libgl1-mesa-glx_20.0.8-0ubuntu1~18.04.1_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [  9%] [#####.....................................................] 8Unpacking libgl1-mesa-glx:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# 7Progress: [ 18%] [##########................................................] 87Progress: [ 27%] [###############...........................................] 8Selecting previously unselected package xvfb.
# Preparing to unpack .../xvfb_2%3a1.19.6-1ubuntu4.10_amd64.deb ...
# 7Progress: [ 36%] [#####################.....................................] 8Unpacking xvfb (2:1.19.6-1ubuntu4.10) ...
# 7Progress: [ 45%] [##########################................................] 87Progress: [ 55%] [###############################...........................] 8Setting up xvfb (2:1.19.6-1ubuntu4.10) ...
# 7Progress: [ 64%] [####################################......................] 87Progress: [ 73%] [##########################################................] 8Setting up libgl1-mesa-glx:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# 7Progress: [ 82%] [###############################################...........] 87Progress: [ 91%] [####################################################......] 8Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
#
# 78

# %%
#!conda activate azureml_py38_PT_TF
# %conda install -c conda-forge vtk -n base -y
# %conda install -c conda-forge pyvista -n base -y
# %conda install -c conda-forge ipyvtklink -n base -y
# %conda install -c conda-forge meshio -n base -y
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Building graph of deps:   0%|          | 0/371 [00:00<?, ?it/s]
# Examining lcms2:   0%|          | 0/371 [00:00<?, ?it/s]
# Examining jinja2:   0%|          | 1/371 [00:00<00:10, 35.50it/s]
# Examining cytoolz:   1%|          | 2/371 [00:04<14:32,  2.37s/it]
# Examining cytoolz:   1%|          | 3/371 [00:04<09:42,  1.58s/it]
# Examining pip:   1%|          | 3/371 [00:05<09:42,  1.58s/it]
# Examining pip:   1%|          | 4/371 [00:05<07:38,  1.25s/it]
# Examining ipycanvas:   1%|          | 4/371 [00:40<07:38,  1.25s/it]
# Examining ipycanvas:   1%|▏         | 5/371 [00:40<1:13:52, 12.11s/it]
# Examining h5py:  90%|████████▉ | 333/371 [47:05<03:53,  6.14s/it]
# Examining h5py:  90%|█████████ | 334/371 [47:05<02:07,  3.45s/it]
# Examining patsy:  90%|█████████ | 334/371 [47:21<02:07,  3.45s/it]
# Examining patsy:  90%|█████████ | 335/371 [47:21<03:57,  6.58s/it]
# Examining munkres:  90%|█████████ | 335/371 [47:27<03:57,  6.58s/it]
# Examining munkres:  91%|█████████ | 336/371 [47:27<03:48,  6.52s/it]
# Examining pkginfo:  91%|█████████ | 336/371 [47:28<03:48,  6.52s/it]
# Examining pkginfo:  91%|█████████ | 337/371 [47:28<02:45,  4.86s/it]
# Examining vs2015_runtime:  91%|█████████ | 337/371 [47:30<02:45,  4.86s/it]
# Examining vs2015_runtime:  91%|█████████ | 338/371 [47:30<02:14,  4.08s/it]
# Examining libarchive:  91%|█████████ | 338/371 [47:30<02:14,  4.08s/it]
# Examining jdcal:  91%|█████████▏| 339/371 [47:30<02:10,  4.08s/it]
# Examining jdcal:  92%|█████████▏| 340/371 [47:30<01:15,  2.43s/it]
# Examining pep8:  92%|█████████▏| 340/371 [47:31<01:15,  2.43s/it]
# Examining pep8:  92%|█████████▏| 341/371 [47:31<00:58,  1.94s/it]
# Examining pandocfilters:  92%|█████████▏| 341/371 [47:31<00:58,  1.94s/it]
# Examining pandocfilters:  92%|█████████▏| 342/371 [47:31<00:43,  1.50s/it]
# Examining arrow:  92%|█████████▏| 342/371 [47:32<00:43,  1.50s/it]
# Examining arrow:  92%|█████████▏| 343/371 [47:32<00:34,  1.21s/it]
# Examining icu:  92%|█████████▏| 343/371 [47:35<00:34,  1.21s/it]
# Examining icu:  93%|█████████▎| 344/371 [47:35<00:52,  1.96s/it]
# Examining ruamel_yaml:  93%|█████████▎| 344/371 [47:35<00:52,  1.96s/it]
# Examining numba:  93%|█████████▎| 345/371 [47:38<00:51,  1.96s/it]
# Examining numba:  93%|█████████▎| 346/371 [47:38<00:43,  1.75s/it]
# Examining pyopenssl:  93%|█████████▎| 346/371 [48:04<00:43,  1.75s/it]
# Examining pyopenssl:  94%|█████████▎| 347/371 [48:04<03:01,  7.57s/it]
# Examining qstylizer:  94%|█████████▎| 347/371 [48:10<03:01,  7.57s/it]
# Examining qstylizer:  94%|█████████▍| 348/371 [48:10<02:40,  6.97s/it]
# Examining clyent:  94%|█████████▍| 348/371 [48:10<02:40,  6.97s/it]
# Examining clyent:  94%|█████████▍| 349/371 [48:10<01:54,  5.21s/it]
# Examining html5lib:  94%|█████████▍| 349/371 [48:12<01:54,  5.21s/it]
# Examining html5lib:  94%|█████████▍| 350/371 [48:12<01:31,  4.33s/it]
# ...
# dask -> distributed[version='>=2.12.0'] -> cytoolz[version='>=0.7.4']
# anaconda==2021.11 -> cytoolz==0.11.0[build='py39h2bbff1b_0|py37he774522_0|py38he774522_0']
# dask -> cytoolz[version='>=0.7.3|>=0.8.2']
#
# Package asttokens conflicts for:
# ipython -> stack_data -> asttokens
# pyjwt -> flake8-import-order -> asttokens
#
# Package qdarkstyle conflicts for:
# spyder -> qdarkstyle[version='3.0.2.*|>=2.8,<3.0|>=2.8|>=2.7']
# anaconda==2021.11 -> qdarkstyle==3.0.2=pyhd3eb1b0_0
# anaconda==2021.11 -> spyder==5.1.5=py39haa95532_1 -> qdarkstyle=3.0.2
#
# Package dask conflicts for:
# distributed -> dask[version='>=0.10.0|>=0.11.0|>=0.11.1|>=0.12.0|>=0.13.0|>=0.14.0|>=0.14.1|>=0.9.0']
# scikit-image -> dask[version='>=0.5']
# anaconda==2021.11 -> dask==2021.10.0=pyhd3eb1b0_0
#
# Package libclang conflicts for:
# pyqt -> qt[version='>=5.12.9,<5.13.0a0'] -> libclang[version='>=10.0.1,<11.0a0|>=11.0.0,<12.0a0|>=11.0.1,<12.0a0|>=9.0.0,<10.0a0']
# qt -> libclang[version='>=10.0.1,<11.0a0|>=11.0.0,<12.0a0|>=11.0.1,<12.0a0|>=9.0.0,<10.0a0|>=8.0.0,<9.0a0']
#
# Package networkx conflicts for:
# anaconda==2021.11 -> networkx==2.6.3=pyhd3eb1b0_0
# scikit-image -> networkx[version='>=1.8,<2.0|>=1.8|>=2.0|>=2.2']
# anaconda==2021.11 -> scikit-image==0.18.3=py39hf11a4ad_0 -> networkx[version='>=2.0']
#
# Package iniconfig conflicts for:
# nltk -> pytest -> iniconfig
# anaconda==2021.11 -> iniconfig==1.1.1=pyhd3eb1b0_0
# anaconda==2021.11 -> pytest==6.2.4=py39haa95532_2 -> iniconfig
# astropy -> pytest -> iniconfig
# pytest -> iniconfig
#
# Package libzopfli conflicts for:
# anaconda==2021.11 -> libzopfli==1.0.3=ha925a31_0
# tifffile -> imagecodecs[version='>=2021.11.20'] -> libzopfli[version='>=1.0.3,<1.1.0a0']
# anaconda==2021.11 -> imagecodecs==2021.8.26=py39ha1f97ea_0 -> libzopfli[version='>=1.0.3,<1.1.0a0']
# imagecodecs -> libzopfli[version='>=1.0.3,<1.1.0a0']
#
# Package glob2 conflicts for:
# anaconda==2021.11 -> glob2==0.7=pyhd3eb1b0_0
# conda-build -> glob2[version='>=0.6']
#
# Package python-slugify conflicts for:
# spyder -> cookiecutter[version='>=1.6.0'] -> python-slugify[version='>=4.0.0']
# anaconda==2021.11 -> cookiecutter==1.7.2=pyhd3eb1b0_0 -> python-slugify[version='>=4.0.0']
# cookiecutter -> python-slugify[version='>=4.0.0']
# anaconda==2021.11 -> python-slugify==5.0.2=pyhd3eb1b0_0
#
# Package pbr conflicts for:
# mock -> pbr[version='>=1.3']
# pytables -> mock -> pbr[version='>=1.3']
#
# Package spyder-kernels conflicts for:
# spyder -> spyder-kernels[version='0.*|>=0.1,<1|>=0.4.2,<1|>=0.4.3,<1|>=0.5.0,<1|>=1.10.0,<1.11.0|>=1.10.1,<1.11.0|>=1.10.2,<1.11.0|>=2.0.1,<2.1.0|>=2.0.2,<2.1.0|>=2.0.3,<2.1.0|>=2.0.4,<2.1.0|>=2.1.0,<2.2.0|>=2.1.1,<2.2.0|>=2.2.0,<2.3.0|>=2.2.1,<2.3.0|>=1.9.4,<1.10.0|>=1.9.2,<1.10.0|>=1.9.1,<1.10.0|>=1.9.0,<1.10.0|>=1.8.1,<1.9.0|>=1.8.1,<2.0.0|<1.0']
# anaconda==2021.11 -> spyder==5.1.5=py39haa95532_1 -> spyder-kernels[version='>=2.1.1,<2.2.0']
# anaconda==2021.11 -> spyder-kernels==2.1.3[build='py39haa95532_0|py37haa95532_0|py38haa95532_0']
#
# Package jupyterlab conflicts for:
# _ipyw_jlab_nb_ext_conf -> jupyterlab
# anaconda==2021.11 -> jupyterlab==3.2.1=pyhd3eb1b0_1
#
# Package python-jsonrpc-server conflicts for:
# spyder -> python-language-server[version='>=0.36.2,<1.0.0'] -> python-jsonrpc-server[version='>=0.3.2|>=0.4.0']
# pyls-spyder -> python-language-server[version='>=0.36.2'] -> python-jsonrpc-server[version='>=0.1.0|>=0.3.2|>=0.4.0']
#
# Package three-merge conflicts for:
# anaconda==2021.11 -> spyder==5.1.5=py39haa95532_1 -> three-merge[version='>=0.1.1']
# anaconda==2021.11 -> three-merge==0.1.1=pyhd3eb1b0_0
# spyder -> three-merge[version='>=0.1.1']
#
# Package pympler conflicts for:
# pytest -> attrs[version='>=17.2.0'] -> pympler
# spyder -> pympler
# attrs -> pympler
#
# Package daal conflicts for:
# daal4py -> daal[version='2020.3|>=2020.3,<2021.0a0|>=2020.3|>=2020.2|>=2020.2,<2021.0a0']
# scikit-learn-intelex -> daal4py==2020.3.1 -> daal[version='2020.3|>=2020.3,<2021.0a0|>=2020.3']
#
# Package tinycss conflicts for:
# spyder -> qstylizer[version='>=0.1.10'] -> tinycss[version='>=0.4,<1.0']
# qstylizer -> tinycss[version='>=0.4,<1.0']
# anaconda==2021.11 -> tinycss==0.4=pyhd3eb1b0_1002
# anaconda==2021.11 -> qstylizer==0.1.10=pyhd3eb1b0_0 -> tinycss[version='>=0.4,<1.0']
#
# Package anyio conflicts for:
# nbclassic -> jupyter_server[version='>=1.8.0,<2.0.0'] -> anyio[version='>=2.0.2|>=2.0.2,<3|>=3.0.1,<4|>=3.1.0,<4']
# anaconda==2021.11 -> jupyter_server==1.4.1=py39haa95532_0 -> anyio[version='>=2.0.2']
# jupyter_server -> anyio[version='>=2.0.2|>=2.0.2,<3|>=3.0.1,<4|>=3.1.0,<4']
# jupyterlab_server -> jupyter_server[version='>=1.4,<2'] -> anyio[version='>=2.0.2|>=2.0.2,<3|>=3.0.1,<4|>=3.1.0,<4']
# jupyterlab -> jupyter_server[version='>=1.4,<2'] -> anyio[version='>=2.0.2|>=2.0.2,<3|>=3.0.1,<4|>=3.1.0,<4']
# anaconda==2021.11 -> anyio==2.2.0[build='py38haa95532_2|py39haa95532_2|py37haa95532_2']
#
# Package menuinst conflicts for:
# conda-token -> conda[version='>=4.3'] -> menuinst[version='>=1.4.11,<2']
# conda[version='>=4.11.0'] -> menuinst[version='>=1.4.11,<2']
# conda-build -> conda[version='>=4.5'] -> menuinst[version='>=1.4.11,<2']
# anaconda==2021.11 -> menuinst==1.4.18[build='py39h59b6b97_0|py37h59b6b97_0|py38h59b6b97_0']
#
# Package winpty conflicts for:
# pywinpty -> winpty[version='>=0.4.3,<1.0a0']
# anaconda==2021.11 -> pywinpty==0.5.7=py39haa95532_0 -> winpty
# terminado -> pywinpty[version='>=1.1,!=2.0.0,!=2.0.1,!=2.0.2'] -> winpty[version='>=0.4.3,<1.0a0']
# anaconda==2021.11 -> winpty==0.4.3=4
#
# Package nomkl conflicts for:
# numexpr -> nomkl
# pandas -> numexpr[version='>=2.7.1'] -> nomkl
# pytables -> numexpr -> nomkl
#
# Package pysocks conflicts for:
# anaconda==2021.11 -> urllib3==1.26.7=pyhd3eb1b0_0 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
# requests -> urllib3[version='>=1.21.1,<1.27'] -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
# urllib3 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
# anaconda==2021.11 -> pysocks==1.7.1[build='py37_1|py39haa95532_0|py38haa95532_0']
#
# Package helpdev conflicts for:
# qdarkstyle -> helpdev[version='>=0.6.10']
# spyder -> qdarkstyle[version='>=2.8,<3.0'] -> helpdev[version='>=0.6.10']
#
# Package rtree conflicts for:
# anaconda==2021.11 -> rtree==0.9.7[build='py38h2eaa2aa_1|py39h2eaa2aa_1|py37h2eaa2aa_1']
# spyder -> rtree[version='>=0.8.3|>=0.9.4|>=0.9.7']
# anaconda==2021.11 -> spyder==5.1.5=py39haa95532_1 -> rtree[version='>=0.9.7']
#
# Package flake8 conflicts for:
# anaconda==2021.11 -> flake8==3.9.2=pyhd3eb1b0_0
# python-lsp-black -> python-lsp-server -> flake8[version='>=3.8.0|>=3.8.0,<4.0.0|>=4.0.0,<4.1.0']
# pyjwt -> flake8
# anaconda==2021.11 -> python-lsp-server==1.2.4=pyhd3eb1b0_0 -> flake8[version='>=3.8.0,<4.0.0']
# pyjwt -> pep8-naming -> flake8[version='>=3.9.1']
# python-lsp-server -> flake8[version='>=3.8.0|>=3.8.0,<4.0.0|>=4.0.0,<4.1.0']
# spyder -> python-lsp-server[version='>=1.3.2,<1.4.0'] -> flake8[version='>=3.8.0|>=3.8.0,<4.0.0|>=4.0.0,<4.1.0']
# pyls-spyder -> python-lsp-server[version='>=1.0.1'] -> flake8[version='>=3.8.0|>=3.8.0,<4.0.0|>=4.0.0,<4.1.0']
#
# Package sphinxcontrib conflicts for:
# sphinxcontrib-websupport -> sphinxcontrib
# sphinx -> sphinxcontrib-websupport -> sphinxcontrib
# anaconda==2021.11 -> sphinxcontrib==1.0[build='py37_1|py39haa95532_1|py38_1']
# anaconda==2021.11 -> sphinxcontrib-websupport==1.2.4=py_0 -> sphinxcontrib
#
# Package curio conflicts for:
# anyio -> curio
# jupyter_server -> anyio[version='>=2.0.2,<3'] -> curio
#
# Package backports.shutil_which conflicts for:
# pywinpty -> backports.shutil_which
# terminado -> pywinpty[version='>=0.5,<1'] -> backports.shutil_which
#
# Package qstylizer conflicts for:
# anaconda==2021.11 -> spyder==5.1.5=py39haa95532_1 -> qstylizer[version='>=0.1.10']
# spyder -> qstylizer[version='>=0.1.10']
# anaconda==2021.11 -> qstylizer==0.1.10=pyhd3eb1b0_0
#
# Package win_inet_pton conflicts for:
# anaconda==2021.11 -> pysocks==1.7.1=py39haa95532_0 -> win_inet_pton
# urllib3 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7'] -> win_inet_pton
# anaconda==2021.11 -> win_inet_pton==1.1.0[build='py39haa95532_0|py37haa95532_0|py38haa95532_0']
# pysocks -> win_inet_pton
#
# Package cached-property conflicts for:
# h5py -> cached-property
# anaconda==2021.11 -> h5py==3.2.1=py39h3de5c98_0 -> cached-property
# anaconda==2021.11 -> cached-property==1.5.2=py_0
#
# Package conda conflicts for:
# conda-build -> conda[version='>=4.1,<4.3|>=4.1|>=4.1,<4.4|>=4.3|>=4.5']
# anaconda==2021.11 -> conda-token==0.3.0=pyhd3eb1b0_0 -> conda[version='>=4.3']
# anaconda-navigator -> conda-token -> conda[version='>=4.3']
# conda-token -> conda[version='>=4.3']
#
# Package blis conflicts for:
# scipy -> libblas[version='>=3.8.0,<4.0a0'] -> blis[version='0.5.1.*|0.5.2|0.6.0|0.6.1|0.7.0|0.8.0|0.8.0|0.8.1|>=0.5.2,<0.5.3.0a0',build='h2fa13f4_0|h8d14728_0|h8d14728_1|h8d14728_0|h8d14728_1|h62dcd97_1|h2fa13f4_0|h2fa13f4_0']
# numpy -> libblas[version='>=3.8.0,<4.0a0'] -> blis[version='0.5.1.*|0.5.2|0.6.0|0.6.1|0.7.0|0.8.0|0.8.0|0.8.1|>=0.5.2,<0.5.3.0a0',build='h2fa13f4_0|h8d14728_0|h8d14728_1|h8d14728_0|h8d14728_1|h62dcd97_1|h2fa13f4_0|h2fa13f4_0']
# blas -> libblas==3.9.0=13_win64_blis -> blis[version='0.5.1.*|0.5.2|0.6.0|0.6.1|0.7.0|0.8.0|0.8.0|0.8.1|>=0.5.2,<0.5.3.0a0',build='h2fa13f4_0|h8d14728_0|h8d14728_1|h8d14728_0|h8d14728_1|h62dcd97_1|h2fa13f4_0|h2fa13f4_0']
#
# Package daal4py conflicts for:
# anaconda==2021.11 -> scikit-learn-intelex==2021.3.0=py39haa95532_0 -> daal4py=2021.3.0
# scikit-learn-intelex -> daal4py[version='2020.3.1|2021.2.2|2021.2.3|2021.3.0|2021.4.0|2021.5.0|2021.5.0.*|2021.4.0.*|2021.3.0.*|2021.2.2.*']
# anaconda==2021.11 -> daal4py==2021.3.0[build='py38h757b272_0|py39h757b272_0|py37h757b272_0']
#
# Package s3fs conflicts for:
# distributed -> s3fs[version='>=0.0.6|>=0.0.7|>=0.0.8']
# dask -> distributed[version='>=1.16.0'] -> s3fs[version='>=0.0.6|>=0.0.7|>=0.0.8']
#
# Package py-lief conflicts for:
# conda-build -> py-lief
# anaconda==2021.11 -> py-lief==0.10.1[build='py39hd77b12b_1|py37ha925a31_0|py38ha925a31_0']
#
# Package lxml conflicts for:
# anaconda==2021.11 -> lxml==4.6.3[build='py37h9b66d53_0|py39h9b66d53_0|py38h9b66d53_0']
# pyvista -> meshio[version='>=4.0.3,<5.0'] -> lxml
#
# Package llvm-openmp conflicts for:
# pillow -> libimagequant -> llvm-openmp[version='>=12.0.1']
# numpy -> libflang[version='>=5.0.0'] -> llvm-openmp[version='11.0.1|>=11.0.1']
#
# Package ptyprocess conflicts for:
# anaconda==2021.11 -> pexpect==4.8.0=pyhd3eb1b0_3 -> ptyprocess[version='>=0.5']
# spyder -> ptyprocess[version='>=0.5']
# pexpect -> ptyprocess[version='>=0.5']
# anaconda==2021.11 -> ptyprocess==0.7.0=pyhd3eb1b0_2
#
# Package ecdsa conflicts for:
# spyder -> paramiko -> ecdsa[version='>=0.11,<2.0']
# paramiko -> ecdsa[version='>=0.11,<2.0']
#
# Package tifffile conflicts for:
# anaconda==2021.11 -> scikit-image==0.18.3=py39hf11a4ad_0 -> tifffile[version='>=2019.7.26']
# anaconda==2021.11 -> tifffile==2021.7.2=pyhd3eb1b0_2
# scikit-image -> tifffile[version='>=2019.7.26']
#
# Package pathtools conflicts for:
# watchdog -> pathtools[version='>=0.1.1']
# spyder -> watchdog[version='>=0.10.3'] -> pathtools[version='>=0.1.1']
#
# Package zfp conflicts for:
# imagecodecs -> zfp[version='>=0.5.5,<1.0a0']
# anaconda==2021.11 -> zfp==0.5.5=hd77b12b_6
# anaconda==2021.11 -> imagecodecs==2021.8.26=py39ha1f97ea_0 -> zfp[version='>=0.5.5,<1.0a0']
# tifffile -> imagecodecs[version='>=2021.11.20'] -> zfp[version='>=0.5.5,<1.0a0']
#
# Package notebook-shim conflicts for:
# jupyterlab -> nbclassic[version='>=0.2,<1'] -> notebook-shim[version='>=0.1.0']
# nbclassic -> notebook-shim[version='>=0.1.0']
#
# Package twisted conflicts for:
# prometheus_client -> twisted
# jupyter_server -> prometheus_client -> twisted
# notebook -> prometheus_client -> twisted
#
# Package anaconda-project conflicts for:
# anaconda==2021.11 -> anaconda-project==0.10.1=pyhd3eb1b0_0
# anaconda-navigator -> anaconda-project[version='>=0.4']
#
# Package soupsieve conflicts for:
# conda-build -> beautifulsoup4 -> soupsieve[version='>=1.2']
# anaconda==2021.11 -> soupsieve==2.2.1=pyhd3eb1b0_0
# beautifulsoup4 -> soupsieve[version='>=1.2']
# anaconda==2021.11 -> beautifulsoup4==4.10.0=pyh06a4308_0 -> soupsieve[version='>=1.2']
# nbconvert -> beautifulsoup4 -> soupsieve[version='>=1.2']
#
# Package c-blosc2 conflicts for:
# imagecodecs -> c-blosc2[version='>=2.0.4,<3.0a0']
# tifffile -> imagecodecs[version='>=2021.11.20'] -> c-blosc2[version='>=2.0.4,<3.0a0']
#
# Package keyring conflicts for:
# anaconda==2021.11 -> keyring==23.1.0[build='py39haa95532_0|py37haa95532_0|py38haa95532_0']
# spyder -> keyring[version='>=17.0.0']
# anaconda==2021.11 -> spyder==5.1.5=py39haa95532_1 -> keyring[version='>=17.0.0']
#
# Package pywavelets conflicts for:
# anaconda==2021.11 -> scikit-image==0.18.3=py39hf11a4ad_0 -> pywavelets[version='>=1.1.1']
# anaconda==2021.11 -> pywavelets==1.1.1[build='py39h080aedc_4|py37he774522_2|py38he774522_2']
# scikit-image -> pywavelets[version='>=0.4.0|>=1.1.1']
#
# Package llvmdev conflicts for:
# llvmlite -> llvmdev=9.0
# numba -> llvmlite[version='>=0.33.0,<0.34'] -> llvmdev=9.0
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\wandent\Anaconda3
#
#   added / updated specs:
#     - meshio
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cftime-1.6.0               |   py39h5d4886f_0         161 KB  conda-forge
#     commonmark-0.9.1           |             py_0          46 KB  conda-forge
#     hdf4-4.2.13                |       h712560f_2         1.3 MB
#     libnetcdf-4.6.1            |       hf59b723_4         501 KB
#     meshio-5.3.4               |     pyhd8ed1ab_0         436 KB  conda-forge
#     netcdf4-1.5.7              |   py39hb76ebac_0         329 KB
#     rich-12.0.0                |     pyhd8ed1ab_0         158 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   cftime             conda-forge/win-64::cftime-1.6.0-py39h5d4886f_0
#   commonmark         conda-forge/noarch::commonmark-0.9.1-py_0
#   hdf4               pkgs/main/win-64::hdf4-4.2.13-h712560f_2
#   libnetcdf          pkgs/main/win-64::libnetcdf-4.6.1-hf59b723_4
#   meshio             conda-forge/noarch::meshio-5.3.4-pyhd8ed1ab_0
#   netcdf4            pkgs/main/win-64::netcdf4-1.5.7-py39hb76ebac_0
#   rich               conda-forge/noarch::rich-12.0.0-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages
#
# cftime-1.6.0         | 161 KB    |            |   0%
# cftime-1.6.0         | 161 KB    | 9          |  10%
# cftime-1.6.0         | 161 KB    | ########## | 100%
# cftime-1.6.0         | 161 KB    | ########## | 100%
#
# commonmark-0.9.1     | 46 KB     |            |   0%
# commonmark-0.9.1     | 46 KB     | ########## | 100%
# commonmark-0.9.1     | 46 KB     | ########## | 100%
#
# meshio-5.3.4         | 436 KB    |            |   0%
# meshio-5.3.4         | 436 KB    | 3          |   4%
# meshio-5.3.4         | 436 KB    | ########## | 100%
# meshio-5.3.4         | 436 KB    | ########## | 100%
#
# netcdf4-1.5.7        | 329 KB    |            |   0%
# netcdf4-1.5.7        | 329 KB    | 4          |   5%
# netcdf4-1.5.7        | 329 KB    | ########## | 100%
# netcdf4-1.5.7        | 329 KB    | ########## | 100%
#
# libnetcdf-4.6.1      | 501 KB    |            |   0%
# libnetcdf-4.6.1      | 501 KB    | ####1      |  42%
# libnetcdf-4.6.1      | 501 KB    | ########## | 100%
# libnetcdf-4.6.1      | 501 KB    | ########## | 100%
#
# rich-12.0.0          | 158 KB    |            |   0%
# rich-12.0.0          | 158 KB    | ########## | 100%
# rich-12.0.0          | 158 KB    | ########## | 100%
#
# hdf4-4.2.13          | 1.3 MB    |            |   0%
# hdf4-4.2.13          | 1.3 MB    | ##2        |  22%
# hdf4-4.2.13          | 1.3 MB    | #######9   |  80%
# hdf4-4.2.13          | 1.3 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
matplotlib

Using Colormaps

itkwidgets



ipyvtklink



sphinx_gallery



colorcet



cmocean



imageio-ffmpeg



tqdm



trimesh rtree pyembree

# %%
# All PyVista Samples here: https://docs.pyvista.org/examples/
# Draw a uniform grid
#import pyvista as pv
#import numpy as np
#pv.start_xvfb()
values = np.linspace(0, 10, 1000).reshape((20, 5, 10))
values.shape

# Create the spatial reference
grid = pv.UniformGrid()



# Set the grid dimensions: shape + 1 because we want to inject our values on
#   the CELL data
grid.dimensions = np.array(values.shape) + 1

# Edit the spatial reference
grid.origin = (100, 33, 55.6)  # The bottom left corner of the data set
grid.spacing = (1, 5, 2)  # These are the cell sizes along each axis

# Add the data values to the cell data
grid.cell_data["values"] = values.flatten(order="F")  # Flatten the array!

# Now plot the grid!
grid.plot(show_edges=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [3], in <cell line: 10>()
#       7 values.shape
#       9 # Create the spatial reference
# ---> 10 grid = pv.UniformGrid()
#      14 # Set the grid dimensions: shape + 1 because we want to inject our values on
#      15 #   the CELL data
#      16 grid.dimensions = np.array(values.shape) + 1
#
# AttributeError: module 'pyvista' has no attribute 'UniformGrid'

# %%
# Terrain mesh
import numpy as np

# sphinx_gallery_thumbnail_number = 3
import pyvista as pv
from pyvista import examples
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_182228/2586067295.py in <module>
#       4 # sphinx_gallery_thumbnail_number = 3
#       5 import pyvista as pv
# ----> 6 from pyvista import examples
#
# ImportError: cannot import name 'examples' from 'pyvista' (unknown location)

# %%
dem = examples.download_crater_topo()
dem
# Out:
# UniformGrid (0x7f4afc0f35e0)
#   N Cells:	1677401
#   N Points:	1680000
#   X Bounds:	1.810e+06, 1.831e+06
#   Y Bounds:	5.640e+06, 5.658e+06
#   Z Bounds:	0.000e+00, 0.000e+00
#   Dimensions:	1400, 1200, 1
#   Spacing:	1.500e+01, 1.500e+01, 0.000e+00
#   N Arrays:	1

# %%
subset = dem.extract_subset((500, 900, 400, 800, 0, 0), (5,5,1))
subset.plot(cpos="xy")
# Out:
# ViewInteractiveWidget(height=768, layout=Layout(height='auto', width='100%'), width=1024)

# %%
terrain = subset.warp_by_scalar()
terrain
terrain.plot()
# Out:
# ViewInteractiveWidget(height=768, layout=Layout(height='auto', width='100%'), width=1024)

# %%
# sphinx_gallery_thumbnail_number = 2
import pyvista as pv
from pyvista import examples

# Load St Helens DEM and warp the topography
image = examples.download_st_helens()
mesh = image.warp_by_scalar()

# %%
p = pv.Plotter()
p.add_mesh(image.contour(), line_width=5,)
p.add_mesh(mesh, opacity=0.85, color=True)
p.show()
# Out:
# ViewInteractiveWidget(height=768, layout=Layout(height='auto', width='100%'), width=1024)

# %%
mesh.plot(opacity="linear")
# Out:
# ViewInteractiveWidget(height=768, layout=Layout(height='auto', width='100%'), width=1024)

# %%
# formats that we can read data
# https://docs.pyvista.org/api/utilities/_autosummary/pyvista.read.html?highlight=meshio#

# mesh :"https://github.com/nschloe/meshio
# pv.read()
